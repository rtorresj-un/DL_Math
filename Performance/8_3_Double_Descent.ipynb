# %% [markdown]
# <a href="https://colab.research.google.com/github/udlbook/udlbook/blob/main/Notebooks/Chap08/8_3_Double_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TO DO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: cpu

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Dimensionality of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Dimensionality of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers
  # And ReLU activations between them
  model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model ;

# %%
def fit_model(model, data, n_epoch):

  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()
  # construct SGD optimizer and initialize learning rate and momentum
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)


  x_train = torch.tensor(data['x'].astype('float32'))
  y_train = torch.tensor(data['y'].transpose().astype('long'))
  x_test= torch.tensor(data['x_test'].astype('float32'))
  y_test = torch.tensor(data['y_test'].astype('long'))

  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

  for epoch in range(n_epoch):
    # loop over batches
    for i, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch)
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train).item()
    losses_test= loss_function(pred_test, y_test).item()
    if epoch%100 ==0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TO DO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero?
# 2.   At what capacity do you expect the first minima of the double descent curve to appear?
# 3. At what capacity do you expect the maximum of the double descent curve to appear?

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400]) ;

errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)
total_weights_all = np.zeros_like(hidden_variables)

# loop over the dataset n_epoch times
n_epoch = 1000

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden]) ;
    # Count and store number of weights
    total_weights_all[c_hidden] = count_parameters(model)
    # Train the model
    errors_train, errors_test = fit_model(model, data, n_epoch)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden]= errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.196633, train error 80.90,  test loss 2.180642, test error 79.82
# Epoch   100, train loss 1.856033, train error 69.75,  test loss 1.710603, test error 68.38
# Epoch   200, train loss 1.851435, train error 69.88,  test loss 1.704449, test error 68.03
# Epoch   300, train loss 1.848234, train error 70.03,  test loss 1.707224, test error 68.53
# Epoch   400, train loss 1.848643, train error 69.90,  test loss 1.697503, test error 68.22
# Epoch   500, train loss 1.846089, train error 70.22,  test loss 1.717705, test error 67.68
# Epoch   600, train loss 1.843522, train error 69.50,  test loss 1.710858, test error 67.75
# Epoch   700, train loss 1.845490, train error 69.82,  test loss 1.721794, test error 68.60
# Epoch   800, train loss 1.847965, train error 70.22,  test loss 1.713350, test error 67.57
# Epoch   900, train loss 1.844931, train error 68.95,  test loss 1.712191, test error 68.30
# Training model with   4 hidden variables
# Epoch     0, train loss 2.298640, train error 86.85,  test loss 2.304880, test error 86.18
# Epoch   100, train loss 1.766474, train error 63.20,  test loss 1.619744, test error 60.62
# Epoch   200, train loss 1.670426, train error 58.58,  test loss 1.469957, test error 54.85
# Epoch   300, train loss 1.661563, train error 57.62,  test loss 1.463261, test error 54.72
# Epoch   400, train loss 1.657103, train error 57.10,  test loss 1.459422, test error 54.97
# Epoch   500, train loss 1.654607, train error 57.35,  test loss 1.441915, test error 54.10
# Epoch   600, train loss 1.666855, train error 58.53,  test loss 1.467530, test error 56.03
# Epoch   700, train loss 1.657137, train error 57.15,  test loss 1.456265, test error 54.55
# Epoch   800, train loss 1.651060, train error 57.72,  test loss 1.452475, test error 54.58
# Epoch   900, train loss 1.653235, train error 57.58,  test loss 1.450874, test error 54.58
# Training model with   6 hidden variables
# Epoch     0, train loss 2.281061, train error 86.38,  test loss 2.278056, test error 86.68
# Epoch   100, train loss 1.749133, train error 63.33,  test loss 1.616671, test error 63.45
# Epoch   200, train loss 1.722168, train error 62.10,  test loss 1.601032, test error 62.67
# Epoch   300, train loss 1.699678, train error 61.95,  test loss 1.583946, test error 61.85
# Epoch   400, train loss 1.694538, train error 61.40,  test loss 1.585787, test error 62.15
# Epoch   500, train loss 1.694051, train error 62.10,  test loss 1.592756, test error 62.97
# Epoch   600, train loss 1.689920, train error 61.58,  test loss 1.583133, test error 62.15
# Epoch   700, train loss 1.685961, train error 61.95,  test loss 1.584719, test error 62.72
# Epoch   800, train loss 1.681543, train error 60.50,  test loss 1.579485, test error 61.67
# Epoch   900, train loss 1.683394, train error 61.42,  test loss 1.580416, test error 61.70
# Training model with   8 hidden variables
# Epoch     0, train loss 2.277769, train error 85.85,  test loss 2.272858, test error 85.68
# Epoch   100, train loss 1.540726, train error 53.58,  test loss 1.395570, test error 52.62
# Epoch   200, train loss 1.492921, train error 51.17,  test loss 1.377469, test error 50.88
# Epoch   300, train loss 1.481533, train error 50.78,  test loss 1.374642, test error 50.25
# Epoch   400, train loss 1.472118, train error 50.78,  test loss 1.362998, test error 49.85
# Epoch   500, train loss 1.464840, train error 50.08,  test loss 1.356993, test error 50.30
# Epoch   600, train loss 1.463489, train error 50.03,  test loss 1.349197, test error 49.78
# Epoch   700, train loss 1.451159, train error 49.28,  test loss 1.343013, test error 49.78
# Epoch   800, train loss 1.451618, train error 49.83,  test loss 1.339818, test error 50.30
# Epoch   900, train loss 1.446418, train error 49.35,  test loss 1.341805, test error 49.70
# Training model with  10 hidden variables
# Epoch     0, train loss 2.272628, train error 85.68,  test loss 2.262930, test error 85.72
# Epoch   100, train loss 1.566274, train error 55.35,  test loss 1.405760, test error 54.35
# Epoch   200, train loss 1.507050, train error 52.70,  test loss 1.382784, test error 53.38
# Epoch   300, train loss 1.480006, train error 50.60,  test loss 1.379057, test error 51.70
# Epoch   400, train loss 1.458299, train error 50.65,  test loss 1.384155, test error 52.22
# Epoch   500, train loss 1.445738, train error 49.33,  test loss 1.392976, test error 52.22
# Epoch   600, train loss 1.443267, train error 50.08,  test loss 1.399577, test error 53.03
# Epoch   700, train loss 1.439248, train error 49.20,  test loss 1.402829, test error 52.00
# Epoch   800, train loss 1.441068, train error 49.22,  test loss 1.417671, test error 52.60
# Epoch   900, train loss 1.442316, train error 49.42,  test loss 1.416504, test error 52.58
# Training model with  14 hidden variables
# Epoch     0, train loss 2.277920, train error 84.35,  test loss 2.273886, test error 84.50
# Epoch   100, train loss 1.412164, train error 46.53,  test loss 1.272853, test error 47.05
# Epoch   200, train loss 1.330675, train error 43.47,  test loss 1.278823, test error 46.85
# Epoch   300, train loss 1.302990, train error 43.83,  test loss 1.314807, test error 48.28
# Epoch   400, train loss 1.290129, train error 43.40,  test loss 1.329851, test error 48.50
# Epoch   500, train loss 1.276551, train error 43.50,  test loss 1.341249, test error 48.17
# Epoch   600, train loss 1.263295, train error 42.62,  test loss 1.341967, test error 47.30
# Epoch   700, train loss 1.267121, train error 43.03,  test loss 1.344222, test error 48.33
# Epoch   800, train loss 1.252625, train error 41.75,  test loss 1.357331, test error 48.35
# Epoch   900, train loss 1.248050, train error 41.75,  test loss 1.358506, test error 48.33
# Training model with  18 hidden variables
# Epoch     0, train loss 2.123822, train error 79.15,  test loss 2.081612, test error 78.62
# Epoch   100, train loss 1.348539, train error 45.70,  test loss 1.287881, test error 48.38
# Epoch   200, train loss 1.258202, train error 42.45,  test loss 1.318508, test error 48.58
# Epoch   300, train loss 1.217017, train error 40.10,  test loss 1.333375, test error 48.28
# Epoch   400, train loss 1.195464, train error 40.85,  test loss 1.377405, test error 49.22
# Epoch   500, train loss 1.178537, train error 40.05,  test loss 1.422813, test error 50.30
# Epoch   600, train loss 1.172771, train error 39.47,  test loss 1.443578, test error 50.28
# Epoch   700, train loss 1.157418, train error 38.95,  test loss 1.449548, test error 50.05
# Epoch   800, train loss 1.143462, train error 39.42,  test loss 1.466797, test error 49.90
# Epoch   900, train loss 1.136787, train error 39.05,  test loss 1.515697, test error 50.35
# Training model with  22 hidden variables
# Epoch     0, train loss 2.149341, train error 79.28,  test loss 2.141910, test error 79.75
# Epoch   100, train loss 1.290084, train error 44.08,  test loss 1.370194, test error 51.53
# Epoch   200, train loss 1.156907, train error 39.45,  test loss 1.400093, test error 49.67
# Epoch   300, train loss 1.086933, train error 36.55,  test loss 1.483815, test error 51.08
# Epoch   400, train loss 1.049605, train error 35.30,  test loss 1.563564, test error 51.12
# Epoch   500, train loss 1.025530, train error 34.88,  test loss 1.621360, test error 51.88
# Epoch   600, train loss 1.007768, train error 33.93,  test loss 1.677011, test error 52.08
# Epoch   700, train loss 0.993410, train error 33.90,  test loss 1.708669, test error 51.62
# Epoch   800, train loss 0.992425, train error 33.82,  test loss 1.752521, test error 52.35
# Epoch   900, train loss 0.972570, train error 33.78,  test loss 1.805965, test error 53.05
# Training model with  26 hidden variables
# Epoch     0, train loss 2.086677, train error 78.70,  test loss 2.022741, test error 76.57
# Epoch   100, train loss 1.183115, train error 39.47,  test loss 1.314171, test error 49.85
# Epoch   200, train loss 1.048496, train error 35.28,  test loss 1.432755, test error 50.72
# Epoch   300, train loss 0.978687, train error 33.05,  test loss 1.576363, test error 52.78
# Epoch   400, train loss 0.936108, train error 31.90,  test loss 1.683188, test error 53.95
# Epoch   500, train loss 0.921976, train error 31.95,  test loss 1.790290, test error 53.75
# Epoch   600, train loss 0.892573, train error 30.12,  test loss 1.827170, test error 54.03
# Epoch   700, train loss 0.877021, train error 29.57,  test loss 1.858730, test error 53.58
# Epoch   800, train loss 0.875047, train error 29.88,  test loss 1.905018, test error 53.25
# Epoch   900, train loss 0.844984, train error 28.95,  test loss 1.984068, test error 55.15
# Training model with  30 hidden variables
# Epoch     0, train loss 2.172106, train error 80.22,  test loss 2.137258, test error 78.88
# Epoch   100, train loss 1.079717, train error 35.50,  test loss 1.339745, test error 49.62
# Epoch   200, train loss 0.906029, train error 29.50,  test loss 1.548901, test error 51.22
# Epoch   300, train loss 0.802282, train error 27.30,  test loss 1.741674, test error 51.33
# Epoch   400, train loss 0.744271, train error 24.18,  test loss 1.953737, test error 53.55
# Epoch   500, train loss 0.706214, train error 23.38,  test loss 2.080188, test error 53.55
# Epoch   600, train loss 0.668878, train error 21.82,  test loss 2.222271, test error 53.17
# Epoch   700, train loss 0.668810, train error 22.97,  test loss 2.358538, test error 54.78
# Epoch   800, train loss 0.637138, train error 21.75,  test loss 2.472624, test error 54.15
# Epoch   900, train loss 0.633889, train error 21.18,  test loss 2.570631, test error 55.12
# Training model with  35 hidden variables
# Epoch     0, train loss 2.173558, train error 79.12,  test loss 2.162822, test error 79.65
# Epoch   100, train loss 1.009432, train error 32.40,  test loss 1.402559, test error 50.28
# Epoch   200, train loss 0.808912, train error 26.07,  test loss 1.708559, test error 53.08
# Epoch   300, train loss 0.700197, train error 23.05,  test loss 2.014488, test error 54.25
# Epoch   400, train loss 0.656070, train error 22.50,  test loss 2.289945, test error 55.38
# Epoch   500, train loss 0.614937, train error 20.43,  test loss 2.585467, test error 56.33
# Epoch   600, train loss 0.555905, train error 18.00,  test loss 2.738044, test error 54.67
# Epoch   700, train loss 0.516263, train error 16.43,  test loss 2.996373, test error 55.67
# Epoch   800, train loss 0.518825, train error 16.82,  test loss 3.209170, test error 56.58
# Epoch   900, train loss 0.470379, train error 15.40,  test loss 3.357365, test error 56.42
# Training model with  40 hidden variables
# Epoch     0, train loss 2.097552, train error 77.55,  test loss 2.057473, test error 75.90
# Epoch   100, train loss 0.892960, train error 29.65,  test loss 1.461289, test error 50.17
# Epoch   200, train loss 0.619848, train error 20.55,  test loss 1.983225, test error 51.10
# Epoch   300, train loss 0.510134, train error 17.45,  test loss 2.676308, test error 54.55
# Epoch   400, train loss 0.405773, train error 13.93,  test loss 3.333466, test error 55.55
# Epoch   500, train loss 0.359832, train error 12.95,  test loss 4.093161, test error 56.70
# Epoch   600, train loss 0.334217, train error 12.00,  test loss 4.638080, test error 56.20
# Epoch   700, train loss 0.324336, train error 11.47,  test loss 5.441336, test error 56.95
# Epoch   800, train loss 0.285344, train error 10.85,  test loss 5.983838, test error 56.70
# Epoch   900, train loss 0.308868, train error 10.75,  test loss 6.668946, test error 58.17
# Training model with  45 hidden variables
# Epoch     0, train loss 2.153891, train error 79.12,  test loss 2.126428, test error 79.70
# Epoch   100, train loss 0.837415, train error 26.88,  test loss 1.538049, test error 51.80
# Epoch   200, train loss 0.504634, train error 15.80,  test loss 2.187635, test error 52.65
# Epoch   300, train loss 0.364543, train error 12.03,  test loss 3.189675, test error 54.60
# Epoch   400, train loss 0.232234, train error 7.40,  test loss 4.402069, test error 55.90
# Epoch   500, train loss 0.141341, train error 4.00,  test loss 5.627691, test error 55.70
# Epoch   600, train loss 0.157980, train error 5.35,  test loss 6.585983, test error 55.97
# Epoch   700, train loss 0.104791, train error 3.45,  test loss 7.521886, test error 55.40
# Epoch   800, train loss 0.009755, train error 0.00,  test loss 8.500038, test error 55.90
# Epoch   900, train loss 0.006684, train error 0.00,  test loss 9.079508, test error 56.00
# Training model with  50 hidden variables
# Epoch     0, train loss 2.126197, train error 78.22,  test loss 2.112896, test error 78.82
# Epoch   100, train loss 0.701900, train error 22.05,  test loss 1.571766, test error 50.10
# Epoch   200, train loss 0.324425, train error 8.53,  test loss 2.645736, test error 53.45
# Epoch   300, train loss 0.160673, train error 4.22,  test loss 4.146287, test error 55.15
# Epoch   400, train loss 0.032831, train error 0.03,  test loss 5.769930, test error 55.78
# Epoch   500, train loss 0.014092, train error 0.00,  test loss 6.787741, test error 55.45
# Epoch   600, train loss 0.008750, train error 0.00,  test loss 7.455483, test error 55.47
# Epoch   700, train loss 0.006178, train error 0.00,  test loss 7.960172, test error 55.67
# Epoch   800, train loss 0.004729, train error 0.00,  test loss 8.355653, test error 55.62
# Epoch   900, train loss 0.003811, train error 0.00,  test loss 8.673029, test error 55.72
# Training model with  55 hidden variables
# Epoch     0, train loss 2.155108, train error 80.53,  test loss 2.134289, test error 79.88
# Epoch   100, train loss 0.663847, train error 20.00,  test loss 1.575474, test error 49.33
# Epoch   200, train loss 0.250887, train error 6.15,  test loss 2.878556, test error 53.25
# Epoch   300, train loss 0.047465, train error 0.05,  test loss 4.654494, test error 54.85
# Epoch   400, train loss 0.015777, train error 0.00,  test loss 5.754788, test error 54.97
# Epoch   500, train loss 0.008767, train error 0.00,  test loss 6.414958, test error 55.15
# Epoch   600, train loss 0.005985, train error 0.00,  test loss 6.880599, test error 55.25
# Epoch   700, train loss 0.004424, train error 0.00,  test loss 7.241300, test error 55.22
# Epoch   800, train loss 0.003503, train error 0.00,  test loss 7.527755, test error 55.33
# Epoch   900, train loss 0.002865, train error 0.00,  test loss 7.774945, test error 55.42
# Training model with  60 hidden variables
# Epoch     0, train loss 2.103178, train error 78.55,  test loss 2.082290, test error 77.95
# Epoch   100, train loss 0.530064, train error 15.65,  test loss 1.711636, test error 49.58
# Epoch   200, train loss 0.119483, train error 1.57,  test loss 3.235174, test error 53.00
# Epoch   300, train loss 0.020893, train error 0.00,  test loss 4.517726, test error 53.22
# Epoch   400, train loss 0.009774, train error 0.00,  test loss 5.201029, test error 53.40
# Epoch   500, train loss 0.006069, train error 0.00,  test loss 5.640898, test error 53.62
# Epoch   600, train loss 0.004331, train error 0.00,  test loss 5.963778, test error 53.70
# Epoch   700, train loss 0.003320, train error 0.00,  test loss 6.227803, test error 53.78
# Epoch   800, train loss 0.002655, train error 0.00,  test loss 6.437059, test error 53.75
# Epoch   900, train loss 0.002209, train error 0.00,  test loss 6.619779, test error 53.62
# Training model with  70 hidden variables
# Epoch     0, train loss 2.044552, train error 76.25,  test loss 1.988465, test error 75.90
# Epoch   100, train loss 0.376615, train error 9.57,  test loss 1.930873, test error 51.60
# Epoch   200, train loss 0.032933, train error 0.00,  test loss 3.471631, test error 52.72
# Epoch   300, train loss 0.011317, train error 0.00,  test loss 4.247842, test error 53.28
# Epoch   400, train loss 0.006249, train error 0.00,  test loss 4.665158, test error 53.20
# Epoch   500, train loss 0.004201, train error 0.00,  test loss 4.960420, test error 53.35
# Epoch   600, train loss 0.003107, train error 0.00,  test loss 5.183549, test error 53.17
# Epoch   700, train loss 0.002434, train error 0.00,  test loss 5.368247, test error 53.05
# Epoch   800, train loss 0.001988, train error 0.00,  test loss 5.521578, test error 53.17
# Epoch   900, train loss 0.001671, train error 0.00,  test loss 5.652381, test error 53.28
# Training model with  80 hidden variables
# Epoch     0, train loss 2.018222, train error 76.20,  test loss 1.967207, test error 76.65
# Epoch   100, train loss 0.230237, train error 3.88,  test loss 2.174111, test error 51.55
# Epoch   200, train loss 0.019778, train error 0.00,  test loss 3.493377, test error 52.38
# Epoch   300, train loss 0.007939, train error 0.00,  test loss 4.054878, test error 52.60
# Epoch   400, train loss 0.004711, train error 0.00,  test loss 4.384892, test error 52.78
# Epoch   500, train loss 0.003244, train error 0.00,  test loss 4.615659, test error 52.80
# Epoch   600, train loss 0.002443, train error 0.00,  test loss 4.796355, test error 52.80
# Epoch   700, train loss 0.001939, train error 0.00,  test loss 4.941617, test error 52.83
# Epoch   800, train loss 0.001595, train error 0.00,  test loss 5.065666, test error 52.90
# Epoch   900, train loss 0.001348, train error 0.00,  test loss 5.171647, test error 53.00
# Training model with  90 hidden variables
# Epoch     0, train loss 2.003138, train error 74.43,  test loss 1.951413, test error 75.45
# Epoch   100, train loss 0.148501, train error 1.45,  test loss 2.204913, test error 51.88
# Epoch   200, train loss 0.015099, train error 0.00,  test loss 3.299508, test error 52.70
# Epoch   300, train loss 0.006601, train error 0.00,  test loss 3.738063, test error 52.85
# Epoch   400, train loss 0.004057, train error 0.00,  test loss 4.008838, test error 53.08
# Epoch   500, train loss 0.002843, train error 0.00,  test loss 4.205810, test error 53.22
# Epoch   600, train loss 0.002166, train error 0.00,  test loss 4.357404, test error 53.30
# Epoch   700, train loss 0.001730, train error 0.00,  test loss 4.481181, test error 53.08
# Epoch   800, train loss 0.001433, train error 0.00,  test loss 4.586797, test error 53.05
# Epoch   900, train loss 0.001216, train error 0.00,  test loss 4.678655, test error 53.08
# Training model with 100 hidden variables
# Epoch     0, train loss 1.997029, train error 73.82,  test loss 1.947715, test error 74.88
# Epoch   100, train loss 0.089753, train error 0.05,  test loss 2.300845, test error 52.03
# Epoch   200, train loss 0.012037, train error 0.00,  test loss 3.171222, test error 51.78
# Epoch   300, train loss 0.005649, train error 0.00,  test loss 3.539726, test error 52.08
# Epoch   400, train loss 0.003535, train error 0.00,  test loss 3.772392, test error 52.10
# Epoch   500, train loss 0.002518, train error 0.00,  test loss 3.941776, test error 52.12
# Epoch   600, train loss 0.001930, train error 0.00,  test loss 4.074097, test error 52.22
# Epoch   700, train loss 0.001551, train error 0.00,  test loss 4.184443, test error 52.25
# Epoch   800, train loss 0.001289, train error 0.00,  test loss 4.276913, test error 52.25
# Epoch   900, train loss 0.001098, train error 0.00,  test loss 4.357261, test error 52.28
# Training model with 120 hidden variables
# Epoch     0, train loss 1.986096, train error 73.85,  test loss 1.929705, test error 75.00
# Epoch   100, train loss 0.049512, train error 0.00,  test loss 2.248582, test error 49.53
# Epoch   200, train loss 0.009510, train error 0.00,  test loss 2.866423, test error 49.70
# Epoch   300, train loss 0.004706, train error 0.00,  test loss 3.150670, test error 49.83
# Epoch   400, train loss 0.003006, train error 0.00,  test loss 3.332206, test error 49.85
# Epoch   500, train loss 0.002171, train error 0.00,  test loss 3.465779, test error 49.80
# Epoch   600, train loss 0.001678, train error 0.00,  test loss 3.572752, test error 49.70
# Epoch   700, train loss 0.001357, train error 0.00,  test loss 3.659256, test error 49.75
# Epoch   800, train loss 0.001132, train error 0.00,  test loss 3.734906, test error 49.75
# Epoch   900, train loss 0.000968, train error 0.00,  test loss 3.799165, test error 49.90
# Training model with 140 hidden variables
# Epoch     0, train loss 1.945242, train error 71.75,  test loss 1.885789, test error 73.20
# Epoch   100, train loss 0.036072, train error 0.00,  test loss 2.137955, test error 49.62
# Epoch   200, train loss 0.008077, train error 0.00,  test loss 2.629100, test error 50.17
# Epoch   300, train loss 0.004168, train error 0.00,  test loss 2.864197, test error 50.20
# Epoch   400, train loss 0.002706, train error 0.00,  test loss 3.016498, test error 50.22
# Epoch   500, train loss 0.001969, train error 0.00,  test loss 3.132102, test error 50.15
# Epoch   600, train loss 0.001531, train error 0.00,  test loss 3.222466, test error 50.15
# Epoch   700, train loss 0.001242, train error 0.00,  test loss 3.297794, test error 50.15
# Epoch   800, train loss 0.001041, train error 0.00,  test loss 3.362626, test error 50.17
# Epoch   900, train loss 0.000892, train error 0.00,  test loss 3.418833, test error 50.15
# Training model with 160 hidden variables
# Epoch     0, train loss 1.942804, train error 70.45,  test loss 1.876563, test error 72.50
# Epoch   100, train loss 0.027854, train error 0.00,  test loss 2.185845, test error 50.53
# Epoch   200, train loss 0.007144, train error 0.00,  test loss 2.597870, test error 49.80
# Epoch   300, train loss 0.003759, train error 0.00,  test loss 2.805393, test error 49.67
# Epoch   400, train loss 0.002474, train error 0.00,  test loss 2.941070, test error 49.67
# Epoch   500, train loss 0.001813, train error 0.00,  test loss 3.044203, test error 49.78
# Epoch   600, train loss 0.001416, train error 0.00,  test loss 3.126269, test error 49.95
# Epoch   700, train loss 0.001154, train error 0.00,  test loss 3.194101, test error 49.95
# Epoch   800, train loss 0.000969, train error 0.00,  test loss 3.252249, test error 49.92
# Epoch   900, train loss 0.000832, train error 0.00,  test loss 3.302565, test error 49.95
# Training model with 180 hidden variables
# Epoch     0, train loss 1.943771, train error 72.85,  test loss 1.872179, test error 72.93
# Epoch   100, train loss 0.025644, train error 0.00,  test loss 1.979572, test error 48.20
# Epoch   200, train loss 0.006810, train error 0.00,  test loss 2.324292, test error 48.33
# Epoch   300, train loss 0.003627, train error 0.00,  test loss 2.496561, test error 48.17
# Epoch   400, train loss 0.002394, train error 0.00,  test loss 2.609893, test error 48.12
# Epoch   500, train loss 0.001759, train error 0.00,  test loss 2.696687, test error 48.22
# Epoch   600, train loss 0.001376, train error 0.00,  test loss 2.765202, test error 48.20
# Epoch   700, train loss 0.001122, train error 0.00,  test loss 2.823508, test error 48.22
# Epoch   800, train loss 0.000943, train error 0.00,  test loss 2.872696, test error 48.22
# Epoch   900, train loss 0.000810, train error 0.00,  test loss 2.915373, test error 48.22
# Training model with 200 hidden variables
# Epoch     0, train loss 1.935591, train error 70.45,  test loss 1.862828, test error 72.32
# Epoch   100, train loss 0.020867, train error 0.00,  test loss 2.011312, test error 47.62
# Epoch   200, train loss 0.006016, train error 0.00,  test loss 2.320715, test error 47.30
# Epoch   300, train loss 0.003282, train error 0.00,  test loss 2.482456, test error 47.10
# Epoch   400, train loss 0.002195, train error 0.00,  test loss 2.592243, test error 47.10
# Epoch   500, train loss 0.001623, train error 0.00,  test loss 2.674246, test error 47.12
# Epoch   600, train loss 0.001276, train error 0.00,  test loss 2.740658, test error 47.10
# Epoch   700, train loss 0.001044, train error 0.00,  test loss 2.795213, test error 47.15
# Epoch   800, train loss 0.000880, train error 0.00,  test loss 2.842519, test error 47.12
# Epoch   900, train loss 0.000757, train error 0.00,  test loss 2.883933, test error 47.17
# Training model with 250 hidden variables
# Epoch     0, train loss 1.895913, train error 68.78,  test loss 1.826043, test error 70.60
# Epoch   100, train loss 0.016645, train error 0.00,  test loss 1.969077, test error 48.12
# Epoch   200, train loss 0.005246, train error 0.00,  test loss 2.230152, test error 47.95
# Epoch   300, train loss 0.002916, train error 0.00,  test loss 2.366164, test error 48.12
# Epoch   400, train loss 0.001971, train error 0.00,  test loss 2.461073, test error 47.80
# Epoch   500, train loss 0.001467, train error 0.00,  test loss 2.532279, test error 47.80
# Epoch   600, train loss 0.001158, train error 0.00,  test loss 2.589896, test error 47.92
# Epoch   700, train loss 0.000951, train error 0.00,  test loss 2.638099, test error 47.80
# Epoch   800, train loss 0.000803, train error 0.00,  test loss 2.679602, test error 47.80
# Epoch   900, train loss 0.000693, train error 0.00,  test loss 2.715914, test error 47.95
# Training model with 300 hidden variables
# Epoch     0, train loss 1.893868, train error 69.90,  test loss 1.849819, test error 71.82
# Epoch   100, train loss 0.014661, train error 0.00,  test loss 1.831297, test error 46.72
# Epoch   200, train loss 0.004863, train error 0.00,  test loss 2.050581, test error 46.97
# Epoch   300, train loss 0.002758, train error 0.00,  test loss 2.166938, test error 46.75
# Epoch   400, train loss 0.001875, train error 0.00,  test loss 2.248078, test error 46.90
# Epoch   500, train loss 0.001402, train error 0.00,  test loss 2.309718, test error 46.70
# Epoch   600, train loss 0.001111, train error 0.00,  test loss 2.359966, test error 46.70
# Epoch   700, train loss 0.000914, train error 0.00,  test loss 2.402139, test error 46.65
# Epoch   800, train loss 0.000773, train error 0.00,  test loss 2.438546, test error 46.72
# Epoch   900, train loss 0.000668, train error 0.00,  test loss 2.470150, test error 46.70
# Training model with 400 hidden variables
# Epoch     0, train loss 1.817725, train error 66.20,  test loss 1.762433, test error 69.35
# Epoch   100, train loss 0.011609, train error 0.00,  test loss 1.777645, test error 45.75
# Epoch   200, train loss 0.004141, train error 0.00,  test loss 1.955242, test error 45.78
# Epoch   300, train loss 0.002402, train error 0.00,  test loss 2.055080, test error 45.70
# Epoch   400, train loss 0.001652, train error 0.00,  test loss 2.124341, test error 45.75
# Epoch   500, train loss 0.001245, train error 0.00,  test loss 2.176280, test error 45.80
# Epoch   600, train loss 0.000991, train error 0.00,  test loss 2.219017, test error 45.80
# Epoch   700, train loss 0.000819, train error 0.00,  test loss 2.255080, test error 45.78
# Epoch   800, train loss 0.000695, train error 0.00,  test loss 2.285827, test error 45.75
# Epoch   900, train loss 0.000602, train error 0.00,  test loss 2.313020, test error 45.78

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming data['y'] is available and contains the training examples
num_training_examples = len(data['y'])

# Find the index where total_weights_all is closest to num_training_examples
closest_index = np.argmin(np.abs(np.array(total_weights_all) - num_training_examples))

# Get the corresponding value of hidden variables
hidden_variable_at_num_training_examples = hidden_variables[closest_index]

# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all, 'r-', label='train')
ax.plot(hidden_variables, errors_test_all, 'b-', label='test')

# Add a vertical line at the point where total weights equal the number of training examples
ax.axvline(x=hidden_variable_at_num_training_examples, color='g', linestyle='--', label='N(weights) = N(train)')

ax.set_ylim(0, 100)
ax.set_xlabel('No. hidden variables')
ax.set_ylabel('Error')
ax.legend()
plt.show()
